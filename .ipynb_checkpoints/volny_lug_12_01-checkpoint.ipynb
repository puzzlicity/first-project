# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Евгения, привет!</b>
#
# Меня зовут Евгений Головин, я буду ревьюером твоего проекта. Если ты не против, то предлагаю построить наше общение на "ты" ;) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# В ходе работы я оставил тебе комментарии <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Сейчас объясню, что они значат:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Решение на этом шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  Решение на этом шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев мой комментарий, не удаляй его, он будет очень полезен в случае повторной проверки работы :)
#
# <div class="alert alert-info">
# <b>А свой помечай вот так, чтобы я его не потерял ;)</b>
# </div>
#
# На мои комменатрии можно и нужно реагировать, только делать это стоит так, чтобы твои и мои комменты не смешались: выделяй свои цветами, сильно отличающимися от моих.
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!

# %% [markdown]
#
# <div class="alert alert-info">
# <b> Привет, спасибо за проверку моего проекта, приступаю к работе!</b>
# </div>

# %% [markdown]
# *Проект "Линейные модели в машинном обучении" на примере задачи*
# # Молочное хозяйство "Вольный луг": расширение поголовья и управление рисками.
#
# ## Описание проекта.
#
# ### Цель: отбор коров для покупки по двум критериям:
#
# * удой не менее 6000 кг молока в год
#
# * молоко должно быть вкусным.
#
#
#
# ### Задачи: создать две прогнозные модели для отбора коров:
#
# * первая должна прогнозировать удой коровы (целевой признак - `Удой`);
#
# * вторая должна рассчитывать вероятность получить вкусное молоко от коровы (целевой признак - `Вкус молока`).
#
# ### Описание данных:
#
# Для работы представлены три датасета:
# * `ferma_main.csv`
# * `ferma_dad.csv`
# * `cow_buy.csv`
#
# 1. Файл  `ferma_main.csv` содержит данные о стаде фермера на текущий момент.
#
# Описание данных:
#
# `id` — уникальный идентификатор коровы.
#
# `Удой, кг` — масса молока, которую корова даёт в год (в килограммах).
#
# `ЭКЕ (Энергетическая кормовая единица)` — показатель питательности корма коровы.
#
# `Сырой протеин, г` — содержание сырого протеина в корме (в граммах).
#
# `СПО (Сахаро-протеиновое соотношение)` — отношение сахара к протеину в корме коровы.
#
# `Порода` — порода коровы.
#
# `Тип пастбища` — ландшафт лугов, на которых паслась корова.
#
# `порода папы_быка` — порода папы коровы.
#
# `Жирность,%` — содержание жиров в молоке (в процентах).
#
# `Белок,%` — содержание белков в молоке (в процентах).
#
# `Вкус молока` — оценка вкуса по личным критериям фермера, бинарный признак (`вкусно`, `не вкусно`).
#
# `Возраст` — возраст коровы, бинарный признак (`менее_2_лет`, `более_2_лет`).
#
# Признаки в датасете `ferma_main.csv` можно разделить на группы.
# Характеристики коровы: `id`, `Порода`, `порода папы_быка`, `Возраст`.
# Характеристики корма: `ЭКЕ (Энергетическая кормовая единица)`, `Сырой протеин, г`, `СПО (Сахаро-протеиновое соотношение)`.
# Характеристика пастбища: `Тип пастбища`.
# Характеристики молока: `Удой, кг`, `Жирность,%`, `Белок,%`, `Вкус молока`.
#
# 2. Файл `ferma_dad.csv` хранит имя папы каждой коровы в стаде фермера.
#
# Описание данных:
#
# `id` — уникальный идентификатор коровы.
#
# `Имя Папы` — имя папы коровы.
#
# 3. Файл `cow_buy.csv` — это данные о коровах «ЭкоФермы».
#
# Описание данных:
#
# `Порода` — порода коровы.
#
# `Тип пастбища` — ландшафт лугов, на которых паслась корова.
#
# `порода папы_быка` — порода папы коровы.
#
# `Имя_папы` — имя папы коровы.
#
# `Текущая_жирность,%` — содержание жиров в молоке (в процентах).
#
# `Текущий_уровень_белок,%` — содержание белков в молоке (в процентах).
#
# `Возраст` — возраст коровы, бинарный признак (менее_2_лет, более_2_лет).
#
# Особенности датасета:
#
# * Содержание белков и жиров в молоке указано на момент продажи — когда «ЭкоФерма» (продавец) давала коровам свой корм.
#
# * Параметры корма `ЭКЕ (Энергетическая кормовая единица)`, `Сырой протеин, г` и `СПО (Сахаро-протеиновое соотношение)` отсутствуют. Технологи заказчика пересмотрели подход  к кормлению: для новых коров планируется увеличить значения каждого из этих параметров на 5%.
#
# * Отсутствуют признаки `Удой, кг` и `Вкус молока`.
#
#
# План работы.
#
# 1. Загрузка данных: загружаем три датафрейма, изучаем их. Определяем, соответствуют ли они поставленным задачам.
#
# 2. Предобработка данных: обрабатываем пропуски, дубликаты, определяем типы данных.
#
# 3. Исследовательский анализ данных: статистический анализ, графики признаков.
#
# 4. Корреляционный анализ признаков: изучаем взаимосвязь между признаками, рассчитываем коэффициенты корреляции.
#
# 5. Модели простой линейной регрессии: обучаем три модели линейной регрессии, выбираем самую лучшую по метрикам MSE, MAE, RMSE, R². Проводим анализ остатков. Прогнозируем удой коров, которых хочет купить фермер.
#
# 6. Классификация: обучаем модель логистической регрессии, прогнозируем вкус молока тех коров, которых хочет купить фермер.
#
# 7. Итоговые выводы: отбираем коров, которых может купить фермер с заданными условиями, делаем выводы о работе линейной и логистической регрессии.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Хорошее введение! Есть цель работы, описание данных, не хватает только плана

# %% [markdown]
#
# <div class="alert alert-info">
# <b>Спасибо, добавляю план!</b>
# </div>

# %% [markdown]
# Шаг 1. Загрузка и изучение данных.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

RANDOM_STATE = 42

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1<a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>  Консанты лучше задавать в ячейке с импортами - одно из правил этикета

# %% [markdown]
#
# <div class="alert alert-info">
# <b>Спасибо, исправила!</b>
# </div>

# %%
# !pip install -U scikit-learn

# %%
pip install matplotlib==3.1.0
# Out:
# ...
#   Using cached matplotlib-3.1.0.tar.gz (37.2 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/89/jgt678_s0ljdwtt51jbf1cvm0000gn/T/pip-install-489c275e/matplotlib_c721b170ef914d5da3624c0cf4d80109/setup.py", line 51, in <module>
#           __version__ = versioneer.get_version()
#                         ^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/89/jgt678_s0ljdwtt51jbf1cvm0000gn/T/pip-install-489c275e/matplotlib_c721b170ef914d5da3624c0cf4d80109/versioneer.py", line 1410, in get_version
#           return get_versions()["version"]
#                  ^^^^^^^^^^^^^^
# ...

# %%
try:
    df1 = pd.read_csv('/Users/evgenia/Downloads/ferma_main.csv')
except:
    df1 = pd.read_csv('/datasets/ferma_main.csv')

# %%
def beginning(df):
    print('Обзор данных из файла')
    print('1. Вывод первых строк на экран')
    display(df.head())
    print('---------------------------------------')
    print('2. Проверка типов данных')
    print(df.info())
    print('---------------------------------------')
    print('3. Проверка явных дубликатов:')
    print(df.duplicated().sum())
    print('---------------------------------------')
    print('4. Проверка пропусков:')
    print()
    frame = ({'nan_qty' : df.isna().sum().sort_values(ascending=False),
         'nan_percent' : round((df.isna().mean()*100).sort_values(ascending=False), 2)})
    nan_df = pd.DataFrame(frame)
    nan_df = nan_df.style.background_gradient(axis=0, cmap='YlOrRd')
    display(nan_df)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отличная функция для обзора данных из фаайла! Молодец!

# %%
beginning(df1)
# Out:
# Обзор данных из файла
# 1. Вывод первых строк на экран
#             id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0         1;5863;14                                           2;1743;0
# 1         2;5529;12                                           8;2138;0
# 2  3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 3         4;5895;12                                           4;2012;0
# 4         5;5302;12                                           8;1675;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
# 2                                               59;3
# 3             885;РефлешнСоверинг;Холмистое;Айдиал;3
# 4             885;Вис Бик Айдиал;Равнинные;Соверин;3
#
#                      %;Белок      %;Вкус молока;Возраст
# 0                       58;3     076;вкусно;более_2_лет
# ...

# %% [markdown]
# В первом датасете мы обращаем внимание на то, что:
#
# * есть как минимум явные (может быть, не только явные) дубликаты (5 объектов, но после обработки данных их количество может увеличиться) и пропуски (18 объектов - менее 3%), которые будут обработаны на этапе предобработки.
#
# * несколько названий столбцов сливается в один (id и Удой, Вкус молока и Возраст, СПО, Порода, Тип пастбища, порода папы_быка, Жирность). Единицы измерения тоже переместились в соседний столбец. Между столбцами попали цифры, которые сложно отнести к какой-либо категории (лучше их удалить).
#
# * тип данных -  object, хотя в датасете как минимум 6 числовых характеристик и 6 категориальных.
#
# * в уникальных значениях столбцов нет единообразия - пастбища могут быть и в единственном числе (равнинное), так и во множественном (равнинные).

# %% [markdown]
# Сначала разделим все склеенные столбцы на отдельные и заберем из них данные, которые получилось идентифицировать (что из этог порода, что из этого жирность и т.д.)
# Потом занесем данные в правильные столбцы.

# %%
df1_re = df1['id;Удой'].str.split(';', expand=True)

# %%
df1_re
# Out:
#        0     1   2     3     4
# 0      1  5863  14  None  None
# 1      2  5529  12  None  None
# 2      3  5810  14  1854     0
# 3      4  5895  12  None  None
# 4      5  5302  12  None  None
# ..   ...   ...  ..   ...   ...
# 629  627  5970  14  None  None
# 630  627  5970  14  None  None
# 631  627  5970  14  None  None
# 632  627  5970  14  None  None
# 633  627  5970  14  None  None
#
# [634 rows x 5 columns]

# %%
df1['id']  = df1_re.iloc[:,0]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id
# 0    58;3  076;вкусно;более_2_лет  1
# 1    54;3  079;вкусно;менее_2_лет  2

# %%
df1['udoy, kg'] = df1_re.iloc[:,1]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg
# 0    58;3  076;вкусно;более_2_лет  1     5863
# 1    54;3  079;вкусно;менее_2_лет  2     5529

# %%
df1_re2 = df1.iloc[:, 1].str.split(';', expand=True)

# %%
df1_re2
# Out:
#        0                1          2        3     4
# 0      2             1743          0     None  None
# 1      8             2138          0     None  None
# 2    885  РефлешнСоверинг  Холмистое  Соверин     3
# 3      4             2012          0     None  None
# 4      8             1675          0     None  None
# ..   ...              ...        ...      ...   ...
# 629    4             1837          0     None  None
# 630    4             1837          0     None  None
# 631    4             1837          0     None  None
# 632    4             1837          0     None  None
# 633    4             1837          0     None  None
#
# [634 rows x 5 columns]

# %%
df1_re3 = df1.iloc[:, 2].str.split(';', expand=True)

# %%
df1_re3
# Out:
#        0                1          2        3     4
# 0     89   Вис Бик Айдиал  Равнинное   Айдиал     3
# 1     89   Вис Бик Айдиал  Равнинные  Соверин     3
# 2     59                3       None     None  None
# 3    885  РефлешнСоверинг  Холмистое   Айдиал     3
# 4    885   Вис Бик Айдиал  Равнинные  Соверин     3
# ..   ...              ...        ...      ...   ...
# 629   88  РефлешнСоверинг  Холмистое  Соверин     3
# 630   88  РефлешнСоверинг  Холмистое  Соверин     3
# 631   88  РефлешнСоверинг  Холмистое  Соверин     3
# 632   88  РефлешнСоверинг  Холмистое  Соверин     3
# 633   88  РефлешнСоверинг  Холмистое  Соверин     3
#
# [634 rows x 5 columns]

# %%
df1_re4 = df1.iloc[:, 3].str.split(';', expand=True)

# %%
df1_re4
# Out:
#        0          1            2
# 0     58          3         None
# 1     54          3         None
# 2    074  не вкусно  более_2_лет
# 3      4          3         None
# 4     73          3         None
# ..   ...        ...          ...
# 629   64          3         None
# 630   64          3         None
# 631   64          3         None
# 632   64          3         None
# 633   64          3         None
#
# [634 rows x 3 columns]

# %%
df1_re5 = df1.iloc[:, 4].str.split(';', expand=True)

# %%
df1_re5
# Out:
#        0          1            2
# 0    076     вкусно  более_2_лет
# 1    079     вкусно  менее_2_лет
# 2    NaN        NaN          NaN
# 3    075  не вкусно  более_2_лет
# 4    073     вкусно  менее_2_лет
# ..   ...        ...          ...
# 629  075  не вкусно  более_2_лет
# 630  075  не вкусно  более_2_лет
# 631  075  не вкусно  более_2_лет
# 632  075  не вкусно  более_2_лет
# 633  075  не вкусно  более_2_лет
#
# [634 rows x 3 columns]

# %%
df1['vozrast'] = df1_re5.iloc[:,2]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет

# %%
df1['spo'] = df1_re3.iloc[:, 0]

# %% [markdown]
# Судя по открытым источникам, показатель СПО - это соотношение, которое может колебаться от примерно 0,4 до 0,8 (и теоретически доходить до 1).

# %%
df1['spo'] = df1['spo'].astype(int)
df1['spo']/=100

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast   spo
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет  0.89
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет  0.89

# %% [markdown]
# Судя по открытым источникам, показатель ЭКЕ может составлять более 10 единиц. Ищем наиболее подходящий столбец с такими данными.

# %%
df1['eke'] = df1_re.iloc[:,2]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast   spo eke
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет  0.89  14
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет  0.89  12

# %% [markdown]
# Судя по открытым источникам, сырой протеин может быть более 100, но не более 1000 в расчете на 1 кг корма. Однако в расчете на одну корову цифры более 1000. Поэтому мы надеемся, что определили столбец правильно (однако в реальных условиях мы бы уточнили, верно ли мы распределили числа по столбцам).

# %%
df1['syroy_protein'] = df1_re2.iloc[:, 1]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast   spo eke  \
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет  0.89  14
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет  0.89  12
#
#   syroy_protein
# 0          1743
# 1          2138

# %%
df1['vkus'] = df1_re5.iloc[:,1]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast   spo eke  \
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет  0.89  14
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет  0.89  12
#
#   syroy_protein    vkus
# 0          1743  вкусно
# 1          2138  вкусно

# %%
df1['poroda'] = df1_re3.iloc[:,1]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast   spo eke  \
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет  0.89  14
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет  0.89  12
#
#   syroy_protein    vkus          poroda
# 0          1743  вкусно  Вис Бик Айдиал
# 1          2138  вкусно  Вис Бик Айдиал

# %%
df1['pastbische'] = df1_re3.iloc[:,2]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast   spo eke  \
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет  0.89  14
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет  0.89  12
#
#   syroy_protein    vkus          poroda pastbische
# 0          1743  вкусно  Вис Бик Айдиал  Равнинное
# 1          2138  вкусно  Вис Бик Айдиал  Равнинные

# %%
df1['poroda_papy'] = df1_re3.iloc[:,3]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast   spo eke  \
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет  0.89  14
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет  0.89  12
#
#   syroy_protein    vkus          poroda pastbische poroda_papy
# 0          1743  вкусно  Вис Бик Айдиал  Равнинное      Айдиал
# 1          2138  вкусно  Вис Бик Айдиал  Равнинные     Соверин

# %%
df1['zhirnost, %'] = df1_re3.iloc[:,4]

# %%
df1.head(2)
# Out:
#      id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0  1;5863;14                                           2;1743;0
# 1  2;5529;12                                           8;2138;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
#
#   %;Белок   %;Вкус молока;Возраст id udoy, kg      vozrast   spo eke  \
# 0    58;3  076;вкусно;более_2_лет  1     5863  более_2_лет  0.89  14
# 1    54;3  079;вкусно;менее_2_лет  2     5529  менее_2_лет  0.89  12
#
#   syroy_protein    vkus          poroda pastbische poroda_papy zhirnost, %
# 0          1743  вкусно  Вис Бик Айдиал  Равнинное      Айдиал           3
# 1          2138  вкусно  Вис Бик Айдиал  Равнинные     Соверин           3

# %%
df1['belok, %'] = df1_re4.iloc[:,1]

# %%
df1.head(4)
# Out:
#             id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 0         1;5863;14                                           2;1743;0
# 1         2;5529;12                                           8;2138;0
# 2  3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 3         4;5895;12                                           4;2012;0
#
#    г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 0               89;Вис Бик Айдиал;Равнинное;Айдиал;3
# 1              89;Вис Бик Айдиал;Равнинные;Соверин;3
# 2                                               59;3
# 3             885;РефлешнСоверинг;Холмистое;Айдиал;3
#
#                      %;Белок      %;Вкус молока;Возраст id udoy, kg  \
# 0                       58;3     076;вкусно;более_2_лет  1     5863
# 1                       54;3     079;вкусно;менее_2_лет  2     5529
# 2  074;не вкусно;более_2_лет                        NaN  3     5810
# ...

# %%
df1['belok, %'].unique()
# Out:
# array(['3', 'не вкусно', 'вкусно'], dtype=object)

# %% [markdown]
# В некоторых строках данные были склеены по-другому, и поэтому столбцы заполнились некорректно. Найдем их и попробуем исправить. Для этого выделим некорретно заполненные данные в отдельный датафрейм, а потом объединим.

# %%
df_dif = df1.loc[df1['belok, %']!='3']

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810     NaN
# 14  071;не вкусно;более_2_лет                   NaN  15     6014     NaN
#
#      spo eke    syroy_protein vkus poroda pastbische poroda_papy zhirnost, %  \
# 2   0.59  14  РефлешнСоверинг  NaN      3       None        None        None
# 14  0.71  16   Вис Бик Айдиал  NaN      3       None        None        None
#
#      belok, %
# 2   не вкусно
# 14  не вкусно

# %%
df1_dif = df_dif['id;Удой'].str.split(';', expand=True)

# %%
df1_dif.head(2)
# Out:
#      0     1   2     3  4
# 2    3  5810  14  1854  0
# 14  15  6014  16  1769  0

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Появились предпреждения. Для борьбы с ними могу посоветовать такой прием:
#
#     import warnings
#
#     warnings.filterwarnings("ignore")
#
#
# Но лучше всегда найти причину появлния ошибки

# %% [markdown]
#
# <div class="alert alert-info">
# <b>Спасибо, попробовала прием, постараюсь найти причины!</b>
# </div>

# %%
df_dif['udoy, kg'] = df1_dif.iloc[:,1]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810     NaN
# 14  071;не вкусно;более_2_лет                   NaN  15     6014     NaN
#
#      spo eke    syroy_protein vkus poroda pastbische poroda_papy zhirnost, %  \
# 2   0.59  14  РефлешнСоверинг  NaN      3       None        None        None
# 14  0.71  16   Вис Бик Айдиал  NaN      3       None        None        None
#
#      belok, %
# 2   не вкусно
# 14  не вкусно

# %%
df2_dif = df_dif['%;Белок'].str.split(';', expand=True)

# %%
df2_dif.head(2)
# Out:
#       0          1            2
# 2   074  не вкусно  более_2_лет
# 14  071  не вкусно  более_2_лет

# %%
df_dif['vozrast'] = df2_dif.iloc[:,2]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke    syroy_protein vkus poroda pastbische poroda_papy zhirnost, %  \
# 2   0.59  14  РефлешнСоверинг  NaN      3       None        None        None
# 14  0.71  16   Вис Бик Айдиал  NaN      3       None        None        None
#
#      belok, %
# 2   не вкусно
# 14  не вкусно

# %%
df_dif['vkus'] = df2_dif.iloc[:,1]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke    syroy_protein       vkus poroda pastbische poroda_papy  \
# 2   0.59  14  РефлешнСоверинг  не вкусно      3       None        None
# 14  0.71  16   Вис Бик Айдиал  не вкусно      3       None        None
#
#    zhirnost, %   belok, %
# 2         None  не вкусно
# 14        None  не вкусно

# %%
df3_dif = df_dif.iloc[:, 1].str.split(';', expand=True)

# %%
df3_dif.head(2)
# Out:
#       0                1          2        3  4
# 2   885  РефлешнСоверинг  Холмистое  Соверин  3
# 14   93   Вис Бик Айдиал  Равнинные   Айдиал  3

# %%
df_dif['pastbische'] = df3_dif.iloc[:,2]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke    syroy_protein       vkus poroda pastbische poroda_papy  \
# 2   0.59  14  РефлешнСоверинг  не вкусно      3  Холмистое        None
# 14  0.71  16   Вис Бик Айдиал  не вкусно      3  Равнинные        None
#
#    zhirnost, %   belok, %
# 2         None  не вкусно
# 14        None  не вкусно

# %%
df_dif['poroda'] = df3_dif.iloc[:,1]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke    syroy_protein       vkus           poroda pastbische  \
# 2   0.59  14  РефлешнСоверинг  не вкусно  РефлешнСоверинг  Холмистое
# 14  0.71  16   Вис Бик Айдиал  не вкусно   Вис Бик Айдиал  Равнинные
#
#    poroda_papy zhirnost, %   belok, %
# 2         None        None  не вкусно
# ...

# %%
df_dif['poroda_papy'] = df3_dif.iloc[:,3]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke    syroy_protein       vkus           poroda pastbische  \
# 2   0.59  14  РефлешнСоверинг  не вкусно  РефлешнСоверинг  Холмистое
# 14  0.71  16   Вис Бик Айдиал  не вкусно   Вис Бик Айдиал  Равнинные
#
#    poroda_papy zhirnost, %   belok, %
# 2      Соверин        None  не вкусно
# ...

# %%
df_dif['zhirnost, %'] = df3_dif.iloc[:,4]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke    syroy_protein       vkus           poroda pastbische  \
# 2   0.59  14  РефлешнСоверинг  не вкусно  РефлешнСоверинг  Холмистое
# 14  0.71  16   Вис Бик Айдиал  не вкусно   Вис Бик Айдиал  Равнинные
#
#    poroda_papy zhirnost, %   belok, %
# 2      Соверин           3  не вкусно
# ...

# %%
df_dif['syroy_protein'] = df1_dif.iloc[:,3]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke syroy_protein       vkus           poroda pastbische poroda_papy  \
# 2   0.59  14          1854  не вкусно  РефлешнСоверинг  Холмистое     Соверин
# 14  0.71  16          1769  не вкусно   Вис Бик Айдиал  Равнинные      Айдиал
#
#    zhirnost, %   belok, %
# 2            3  не вкусно
# ...

# %%
df_dif['spo'] = df3_dif.iloc[:,0]

# %%
df_dif['spo'] = df_dif['spo'].astype(int)
df_dif['spo']/=100

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke syroy_protein       vkus           poroda pastbische poroda_papy  \
# 2   8.85  14          1854  не вкусно  РефлешнСоверинг  Холмистое     Соверин
# 14  0.93  16          1769  не вкусно   Вис Бик Айдиал  Равнинные      Айдиал
#
#    zhirnost, %   belok, %
# 2            3  не вкусно
# ...

# %%
df4_dif = df_dif.iloc[:, 2].str.split(';', expand=True)

# %%
df4_dif.head(2)
# Out:
#      0  1
# 2   59  3
# 14  71  3

# %%
df_dif['belok, %'] = df4_dif.iloc[:,1]

# %%
df_dif.head(2)
# Out:
#               id;Удой  кг;ЭКЕ (Энергетическая кормовая единица);Сырой протеин  \
# 2    3;5810;14;1854;0            885;РефлешнСоверинг;Холмистое;Соверин;3
# 14  15;6014;16;1769;0               93;Вис Бик Айдиал;Равнинные;Айдиал;3
#
#     г;СПО (Сахаро-протеиновое соотношение);Порода;Тип пастбища;порода папы_быка;Жирность  \
# 2                                                59;3
# 14                                               71;3
#
#                       %;Белок %;Вкус молока;Возраст  id udoy, kg      vozrast  \
# 2   074;не вкусно;более_2_лет                   NaN   3     5810  более_2_лет
# 14  071;не вкусно;более_2_лет                   NaN  15     6014  более_2_лет
#
#      spo eke syroy_protein       vkus           poroda pastbische poroda_papy  \
# 2   8.85  14          1854  не вкусно  РефлешнСоверинг  Холмистое     Соверин
# 14  0.93  16          1769  не вкусно   Вис Бик Айдиал  Равнинные      Айдиал
#
#    zhirnost, % belok, %
# 2            3        3
# ...

# %%
df1 = df1.loc[df1['belok, %']=='3']

# %% [markdown]
# Склеиваем таблицу из двух частей и удаляем лишние столбцы:

# %%
df1_final = pd.concat([df1, df_dif], axis=0, ignore_index=False)

# %%
len(df1_final)
# Out:
# 634

# %%
df1_final = df1_final.iloc[:, 5:]

# %%
df1_final.head(10)
# Out:
#     id udoy, kg      vozrast   spo eke syroy_protein       vkus  \
# 0    1     5863  более_2_лет  0.89  14          1743     вкусно
# 1    2     5529  менее_2_лет  0.89  12          2138     вкусно
# 3    4     5895  более_2_лет  8.85  12          2012  не вкусно
# 4    5     5302  менее_2_лет  8.85  12          1675     вкусно
# 5    6     5254  менее_2_лет  8.85  12          1806     вкусно
# 6    7     5910  более_2_лет  8.85  13          1792     вкусно
# 7    8     6179  более_2_лет  0.93  14          1806     вкусно
# 8    9     6783  более_2_лет  0.94  14          1918     вкусно
# 9   10     5339  менее_2_лет  8.95  13          1791     вкусно
# 10  11     5591  менее_2_лет  8.95  13          1678     вкусно
#
#              poroda pastbische poroda_papy zhirnost, % belok, %
# 0    Вис Бик Айдиал  Равнинное      Айдиал           3        3
# 1    Вис Бик Айдиал  Равнинные     Соверин           3        3
# 3   РефлешнСоверинг  Холмистое      Айдиал           3        3
# ...

# %%
df1 = df1_final

# %% [markdown]
# На данный момент в датафрейме остались следующие проблемы:
#
# * не исследованы аномалии;
# * не изменен тип данных в числовых столбцах;
# * не приведены к единообразию категории в столбцах.
#
# Вернемся к этим вопросам на этапе предобработки.

# %%
try:
    df2 = pd.read_csv('/Users/evgenia/Downloads/ferma_dad.csv')
except:
    df2 = pd.read_csv('ferma_dad.csv')

# %%
beginning(df2)
# Out:
# Обзор данных из файла
# 1. Вывод первых строк на экран
#   id;Имя Папы
# 0    1;Буйный
# 1  2;Соловчик
# 2     3;Барин
# 3    4;Буйный
# 4     5;Барин
# ---------------------------------------
# 2. Проверка типов данных
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id;Имя Папы  629 non-null    object
# dtypes: object(1)
# memory usage: 5.0+ KB
# None
# ---------------------------------------
# 3. Проверка явных дубликатов:
# 0
# ---------------------------------------
# 4. Проверка пропусков:
# <style type="text/css">
# #T_6c014_row0_col0, #T_6c014_row0_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_6c014">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c014_level0_col0" class="col_heading level0 col0" >nan_qty</th>
# ...

# %% [markdown]
# Мы видим, что нет дубликатов и пропусков, но столбцы опять склеились.

# %%
df2 = df2['id;Имя Папы'].str.split(';', expand=True)

# %%
df2.head(2)
# Out:
#    0         1
# 0  1    Буйный
# 1  2  Соловчик

# %%
df2.columns = ['id', 'imya_papy']

# %%
df2.head()
# Out:
#   id imya_papy
# 0  1    Буйный
# 1  2  Соловчик
# 2  3     Барин
# 3  4    Буйный
# 4  5     Барин

# %% [markdown]
# Во втором датафрейме на данный момент одна проблема - количество элементов в нем не совпадает с количеством элементов первого. Возможно, после удаления дубликатов проблема уйдет.

# %%
try:
    df3 = pd.read_csv('/Users/evgenia/Downloads/cow_buy.csv')
except:
    df3 = pd.read_csv('cow_buy.csv')

# %%
beginning(df3)
# Out:
# Обзор данных из файла
# 1. Вывод первых строк на экран
#   Порода;Тип пастбища;порода папы_быка;Имя_папы;Текущая_жирность  \
# 0         Вис Бик Айдиал;холмистое;Айдиал;Геркулес;3
# 1          Вис Бик Айдиал;равнинное;Соверин;Буйный;3
# 2          РефлешнСоверинг;равнинное;Соверин;Барин;3
# 3          РефлешнСоверинг;холмистое;Айдиал;Буйный;3
# 4          РефлешнСоверинг;равнинное;Айдиал;Буйный;3
#
#   %;Текущий_уровень_белок        %;Возраст
# 0                    58;3  076;более_2_лет
# 1                    54;3  081;менее_2_лет
# 2                    59;3  074;более_2_лет
# 3                     4;3  061;более_2_лет
# 4                    64;3  074;более_2_лет
# ---------------------------------------
# 2. Проверка типов данных
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ...

# %% [markdown]
# Видим, что в датафрейме есть 4 дубликата, склеены столбцы, а также числовые столбцы (жирность, белок) указаны не в числовом формате.

# %%
df3_re = df3.iloc[:, 0].str.split(';', expand=True)

# %%
df3_re.head(3)
# Out:
#                  0          1        2         3  4
# 0   Вис Бик Айдиал  холмистое   Айдиал  Геркулес  3
# 1   Вис Бик Айдиал  равнинное  Соверин    Буйный  3
# 2  РефлешнСоверинг  равнинное  Соверин     Барин  3

# %%
df3_re.columns = ['poroda', 'pastbische', 'poroda_papy', 'umya_papy', 'tek_zhirnost']

# %%
df3_re2 = df3.iloc[:, 1].str.split(';', expand=True)

# %%
df3_re['tek_belok'] = df3_re2.iloc[:, 1]

# %%
df3_re.head(3)
# Out:
#             poroda pastbische poroda_papy umya_papy tek_zhirnost tek_belok
# 0   Вис Бик Айдиал  холмистое      Айдиал  Геркулес            3         3
# 1   Вис Бик Айдиал  равнинное     Соверин    Буйный            3         3
# 2  РефлешнСоверинг  равнинное     Соверин     Барин            3         3

# %%
df3_re3 = df3.iloc[:, 2].str.split(';', expand=True)

# %%
df3_re3.head(3)
# Out:
#      0            1
# 0  076  более_2_лет
# 1  081  менее_2_лет
# 2  074  более_2_лет

# %%
df3_re['vozrast'] = df3_re3.iloc[:, 1]

# %%
df3_re.head(3)
# Out:
#             poroda pastbische poroda_papy umya_papy tek_zhirnost tek_belok  \
# 0   Вис Бик Айдиал  холмистое      Айдиал  Геркулес            3         3
# 1   Вис Бик Айдиал  равнинное     Соверин    Буйный            3         3
# 2  РефлешнСоверинг  равнинное     Соверин     Барин            3         3
#
#        vozrast
# 0  более_2_лет
# 1  менее_2_лет
# 2  более_2_лет

# %%
df3 = df3_re

# %% [markdown]
# Шаг 2. Предобработка данных.

# %% [markdown]
# Проверяем на дубликаты, явные и неявные:

# %%
df1.duplicated().sum()
# Out:
# 5

# %%
df1 = df1.drop_duplicates()

# %%
df1['id'].nunique()
# Out:
# 629

# %%
df1['vozrast'].nunique()
# Out:
# 2

# %%
df1['vkus'].nunique()
# Out:
# 2

# %%
df1['poroda'].nunique()
# Out:
# 2

# %%
df1['pastbische'].nunique()
# Out:
# 3

# %%
df1['poroda_papy'].nunique()
# Out:
# 3

# %%
df1['poroda_papy'].unique()
# Out:
# array(['Айдиал', 'Соверин', 'Айдиалл'], dtype=object)

# %%
df1['zhirnost, %'].nunique()
# Out:
# 2

# %%
df1['belok, %'].nunique()
# Out:
# 1

# %%
df1['pastbische'].unique()
# Out:
# array(['Равнинное', 'Равнинные', 'Холмистое'], dtype=object)

# %% [markdown]
# Мы видим, что столбец с данными о содержании белка несет лишь один вариант значений, и поэтому не является полезным в анализе.
#
# Видим, что столбец с типом пастбища и породой папы следует привести к единообразию.
#
# Видим, что теперь количество строк совпадает со вторым датафреймом.

# %%
df1['pastbische'] = df1['pastbische'].str.replace('Равнинные','Равнинное')

# %%
df1['pastbische'].unique()
# Out:
# array(['Равнинное', 'Холмистое'], dtype=object)

# %%
df1['pastbische'] = df1['pastbische'].str.lower()

# %%
df1['poroda_papy'] = df1['poroda_papy'].str.replace('Айдиалл','Айдиал')

# %%
df1['poroda_papy'].unique()
# Out:
# array(['Айдиал', 'Соверин'], dtype=object)

# %% [markdown]
# Проверим наличие пропусков:

# %%
df1.isna().sum()
# Out:
# id               0
# udoy, kg         0
# vozrast          0
# spo              0
# eke              0
# syroy_protein    0
# vkus             0
# poroda           0
# pastbische       0
# poroda_papy      0
# zhirnost, %      0
# belok, %         0
# dtype: int64

# %% [markdown]
# После обработки данных на первом этапе пропусков не осталось.

# %%
df1['id'] = df1['id'].astype(int)
df1['udoy, kg'] = df1['udoy, kg'].astype(float)
df1['spo'] = df1['spo'].astype(float)
df1['eke'] = df1['eke'].astype(float)
df1['syroy_protein'] = df1['syroy_protein'].astype(float)
df1['zhirnost, %'] = df1['zhirnost, %'].astype(float)
df1['belok, %'] = df1['belok, %'].astype(float)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 629 entries, 0 to 590
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             629 non-null    int64
#  1   udoy, kg       629 non-null    float64
#  2   vozrast        629 non-null    object
#  3   spo            629 non-null    float64
#  4   eke            629 non-null    float64
#  5   syroy_protein  629 non-null    float64
#  6   vkus           629 non-null    object
#  7   poroda         629 non-null    object
#  8   pastbische     629 non-null    object
#  9   poroda_papy    629 non-null    object
#  10  zhirnost, %    629 non-null    float64
#  11  belok, %       629 non-null    float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 63.9+ KB

# %%
df1['udoy, kg'].describe()
# Out:
# count      629.000000
# mean      6188.750397
# std       1644.795489
# min       5204.000000
# 25%       5751.000000
# 50%       6133.000000
# 75%       6501.000000
# max      45616.000000
# Name: udoy, kg, dtype: float64

# %%
df1.boxplot('udoy, kg')
plt.show()
plt.title('Диаграмма размаха: удой молока');

# %% [markdown]
# Значение выше 45000 похоже на выброс, избавимся от него.

# %%
df1 = df1[df1['udoy, kg']<45000]

# %%
df1['spo'].describe()
# Out:
# count    628.000000
# mean       1.397054
# std        1.908911
# min        0.090000
# 25%        0.890000
# 50%        0.930000
# 75%        0.940000
# max        8.950000
# Name: spo, dtype: float64

# %%
df1.boxplot('spo')
plt.show()
plt.title('Диаграмма размаха: СПО');

# %% [markdown]
# Значения выше 8 и близкие к 0 похожи на выбросы, избавимся от них.

# %%
df1 = df1[df1['spo']< 8 ]

# %%
df1 = df1[df1['spo']> 0.2]

# %%
df1['spo'].describe()
# Out:
# count    589.000000
# mean       0.914533
# std        0.032738
# min        0.840000
# 25%        0.890000
# 50%        0.930000
# 75%        0.940000
# max        0.960000
# Name: spo, dtype: float64

# %%
df1['eke'].describe()
# Out:
# count    589.000000
# mean      14.127334
# std        1.320592
# min       10.000000
# 25%       13.000000
# 50%       14.000000
# 75%       15.000000
# max       16.000000
# Name: eke, dtype: float64

# %%
df1['syroy_protein'].describe()
# Out:
# count     589.000000
# mean     1929.925297
# std       184.402873
# min      1660.000000
# 25%      1779.000000
# 50%      1901.000000
# 75%      2073.000000
# max      2349.000000
# Name: syroy_protein, dtype: float64

# %%
df1.boxplot('syroy_protein')
plt.show()
plt.title('Диаграмма размаха: Сырой протеин');

# %% [markdown]
# С точки зрения аномалий, пропусков, дубликатов и типов данныхпервый датафрейм нас устраивает.
# Второй датафрейм тоже:

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         629 non-null    object
#  1   imya_papy  629 non-null    object
# dtypes: object(2)
# memory usage: 10.0+ KB

# %%
df2['id'] = df2['id'].astype(int)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   poroda        20 non-null     object
#  1   pastbische    20 non-null     object
#  2   poroda_papy   20 non-null     object
#  3   umya_papy     20 non-null     object
#  4   tek_zhirnost  20 non-null     object
#  5   tek_belok     20 non-null     object
#  6   vozrast       20 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB

# %%
df3.duplicated().sum()
# Out:
# 9

# %%
df3 = df3.drop_duplicates()

# %%
len(df3)
# Out:
# 11

# %%
df3['tek_belok'].nunique()
# Out:
# 1

# %%
df3['tek_zhirnost'].nunique()
# Out:
# 1

# %%
df3['vozrast'].nunique()
# Out:
# 2

# %%
df3['poroda_papy'].nunique()
# Out:
# 2

# %%
df3['poroda'].nunique()
# Out:
# 2

# %%
df3['umya_papy'].unique()
# Out:
# array(['Геркулес', 'Буйный', 'Барин', 'Соловчик'], dtype=object)

# %%
df3['tek_zhirnost'] = df3['tek_zhirnost'].astype(float)
df3['tek_belok'] = df3['tek_belok'].astype(float)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   poroda        11 non-null     object
#  1   pastbische    11 non-null     object
#  2   poroda_papy   11 non-null     object
#  3   umya_papy     11 non-null     object
#  4   tek_zhirnost  11 non-null     float64
#  5   tek_belok     11 non-null     float64
#  6   vozrast       11 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 704.0+ bytes

# %%
df3.isna().sum()
# Out:
# poroda          0
# pastbische      0
# poroda_papy     0
# umya_papy       0
# tek_zhirnost    0
# tek_belok       0
# vozrast         0
# dtype: int64

# %% [markdown]
# C точки зрения дубликатов, пропусков и типов данных третий датафрейм нас устраивает.

# %% [markdown]
# Промежуточный вывод:
#
# Мы обработали первый датафрейм с точки зрения дубликатов и единообразия в категориях, а также убрали экстремальные значения.
#
# Второй датафрейм не содержал подобных проблем.
#
# В третьем датафрейме мы убрали дубликаты и проверили категориальные значения.

# %% [markdown]
# Шаг 3. Исследовательский анализ данных.

# %%
df1.describe()
# Out:
#                id     udoy, kg         spo         eke  syroy_protein  \
# count  589.000000   589.000000  589.000000  589.000000     589.000000
# mean   332.561969  6159.480475    0.914533   14.127334    1929.925297
# std    174.086229   469.556719    0.032738    1.320592     184.402873
# min      1.000000  5204.000000    0.840000   10.000000    1660.000000
# 25%    187.000000  5788.000000    0.890000   13.000000    1779.000000
# 50%    335.000000  6171.000000    0.930000   14.000000    1901.000000
# 75%    482.000000  6515.000000    0.940000   15.000000    2073.000000
# max    629.000000  7222.000000    0.960000   16.000000    2349.000000
#
#        zhirnost, %  belok, %
# count   589.000000     589.0
# mean      2.994907       3.0
# std       0.071246       0.0
# min       2.000000       3.0
# 25%       3.000000       3.0
# 50%       3.000000       3.0
# 75%       3.000000       3.0
# max       3.000000       3.0

# %% [markdown]
# Мы видим, что:
#
# * удой молока колеблется от 5204 до 7222 кг, среднее значение составляет 6159 кг, а медианное - 6171.
# * СПО колеблется от 0.84 до 0.96, среднее значение - 0.91, медианное - 0.93.
# * ЭКЕ колеблется от 10 до 16, среднее и медианное значения очень близки - 14 и 14.127.
# * сырой протеин колеблется от 1660 до 2349, среднее значение - 1929, медианное - 1901.
# * жирность равно 2-3%, содержание белка - 3%.

# %%
df1['udoy, kg'].hist(bins=20)
plt.title('Удой молока в кг')
plt.ylabel('Количество коров')
plt.xlabel('Удой молока, кг')
plt.show();

# %% [markdown]
# Видим, что удой выше 6750 встречается значительно реже, чем меньший удой.Пики значений - примерно на 6000 и 6500 кг.

# %%
df1['spo'].hist(bins=7)
plt.title('Сахарно-протеиновое соотношение')
plt.ylabel('Количество коров')
plt.xlabel('СПО')
plt.show();

# %% [markdown]
# Видим, что пики значений СПО приходятся на 0.92-0.94, в то время как значения ниже 90 случаются реже.

# %%
df1['eke'].hist(bins=7)
plt.title('ЭКЕ')
plt.ylabel('Количество коров')
plt.xlabel('ЭКЕ')
plt.show();

# %% [markdown]
# Видим, что ЭКЕ практически никогда не бывает менее 11, а пик значений приходится на 15.

# %%
df1['syroy_protein'].hist(bins=10)
plt.title('Сырой протеин')
plt.ylabel('Количество коров')
plt.xlabel('Сырой протеин')
plt.show();

# %% [markdown]
# Мы видим, что количество сырого протеина чаще не превышает 2000.

# %%
df1.groupby('zhirnost, %')['zhirnost, %'].count().plot(kind='pie', ylabel='', title='Жирность молока', figsize=(5,4))
plt.show();

# %%
df1.groupby('zhirnost, %')['zhirnost, %'].count()
# Out:
# zhirnost, %
# 2.0      3
# 3.0    586
# Name: zhirnost, %, dtype: int64

# %% [markdown]
# Видим, что в подавляющем большинстве жирность молока - 3%.

# %%
df1.groupby('belok, %')['belok, %'].count().plot(kind='pie', ylabel='', title='Содержание белка в %', figsize=(5,4))
plt.show();

# %% [markdown]
# Содержание белка в молоке коров, живущих на ферме, одинаковое. Возникает вопрос, насколько значим такой столбец в выборке и не стоит ли от него избавиться, но перед этим оценим содержание белка в молоке в третьем датафрейме.

# %% [markdown]
# Рассмотрим категориальные столбцы первого датафрейма.

# %%
df1.groupby('vozrast')['vozrast'].count()
# Out:
# vozrast
# более_2_лет    497
# менее_2_лет     92
# Name: vozrast, dtype: int64

# %%
df1.groupby('vozrast')['vozrast'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Возраст коров')
plt.show();

# %% [markdown]
# Видим, что в уже имеющемся поголовье большая часть коров старше двух лет, и лишь около 15% коров моложе 2 лет.

# %%
df1.groupby('vkus')['vkus'].count()
# Out:
# vkus
# вкусно       347
# не вкусно    242
# Name: vkus, dtype: int64

# %%
df1.groupby('vkus')['vkus'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Вкус молока')
plt.show();

# %% [markdown]
# Видим, что в текущем поголовье фермера вкусное молоко встречается почти в 1,5 раза чаще невкусного.

# %%
df1.groupby('poroda')['poroda'].count()
# Out:
# poroda
# Вис Бик Айдиал     348
# РефлешнСоверинг    241
# Name: poroda, dtype: int64

# %%
df1.groupby('poroda')['poroda'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Порода коров')
plt.show();

# %% [markdown]
# Видим, что примерно в таком же соотношении, как вкус, находится соотношение пород. Нужно проверить, как соотносятся эти параметры.

# %%
df1[df1['vkus']=='вкусно'].groupby('poroda')['poroda'].count()
# Out:
# poroda
# Вис Бик Айдиал     204
# РефлешнСоверинг    143
# Name: poroda, dtype: int64

# %%
df1[df1['vkus']!='вкусно'].groupby('poroda')['poroda'].count()
# Out:
# poroda
# Вис Бик Айдиал     144
# РефлешнСоверинг     98
# Name: poroda, dtype: int64

# %% [markdown]
# Видим, что обе породы довольно часто встречаются среди коров, которые дают и вкусное, и невкусное молоко. Несмотря на довольно похожее распределение по группам, вкус явно определяется не только породой.

# %%
df1.groupby('pastbische')['pastbische'].count()
# Out:
# pastbische
# равнинное    259
# холмистое    330
# Name: pastbische, dtype: int64

# %%
df1.groupby('pastbische')['pastbische'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Тип пастбища')
plt.show();

# %% [markdown]
# Видим, что холмистое пастбище более распространено, чем равнинное.

# %%
df1.groupby('poroda_papy')['poroda_papy'].count()
# Out:
# poroda_papy
# Айдиал     286
# Соверин    303
# Name: poroda_papy, dtype: int64

# %%
df1.groupby('poroda_papy')['poroda_papy'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Порода папы')
plt.show();

# %% [markdown]
# Породы пап по частоте сопоставимы друг с другом.

# %% [markdown]
# Второй датафрейм содержит только имя папы коров в стаде фермера, поэтому исследовать его статистически мы не будем. Перейдем к третьему датафрейму.

# %%
df3.describe()
# Out:
#        tek_zhirnost  tek_belok
# count          11.0       11.0
# mean            3.0        3.0
# std             0.0        0.0
# min             3.0        3.0
# 25%             3.0        3.0
# 50%             3.0        3.0
# 75%             3.0        3.0
# max             3.0        3.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   poroda        11 non-null     object
#  1   pastbische    11 non-null     object
#  2   poroda_papy   11 non-null     object
#  3   umya_papy     11 non-null     object
#  4   tek_zhirnost  11 non-null     float64
#  5   tek_belok     11 non-null     float64
#  6   vozrast       11 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 704.0+ bytes

# %%
df3.groupby('poroda')['poroda'].count()
# Out:
# poroda
# Вис Бик Айдиал     5
# РефлешнСоверинг    6
# Name: poroda, dtype: int64

# %%
df3.groupby('poroda')['poroda'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Порода коров Экофермы')
plt.show();

# %%
ax = df1['poroda'].hist(alpha=0.5, bins=3, figsize=(5,6))
ax.set_ylabel('Количество коров')
ax.set_xlabel('Породы');
ax.set_title('Породы коров в стаде и на Экоферме');


ax = df3['poroda'].hist(alpha=0.7, bins=3)
plt.legend(['Коровы в стаде', 'Коровы на Экоферме']);
plt.show()

# %% [markdown]
# Мы видим, что в стаде больше коров породы Вис Бик Айдиал, в то время как в выборке с Экофермы больше коров породы Рефлешн Соверинг. С одной стороны, выборка с Экофермы очень маленькая, и такая разница (в одну корову) может не иметь большого значения. С другой стороны, можно точно сказать, что на данный момент в стаде другое соотношение пород (в стаде породы Вис Бик Айдиал точно значительно больше Рефлешн Соверинга).

# %%
df3.groupby('pastbische')['pastbische'].count()
# Out:
# pastbische
# равнинное    6
# холмистое    5
# Name: pastbische, dtype: int64

# %%
df3.groupby('pastbische')['pastbische'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Пастбища Экофермы')
plt.show();

# %%
ax = df1['pastbische'].hist(alpha=0.5, bins=3, figsize=(5,6))
ax.set_ylabel('Количество коров')
ax.set_xlabel('Пастбища');
ax.set_title('Пастбища коров в стаде и на Экоферме');


ax = df3['pastbische'].hist(alpha=0.7, bins=3)
plt.legend(['Коровы в стаде', 'Коровы на Экоферме']);
plt.show()

# %% [markdown]
# Видим, что в стаде заметно больше коров, которые пасутся на холмистых пастбищах, а на Экоферме больше равнинных. Однако выборка маленькая, разница в одну корову может не иметь большого значения. Однако уверенно можно сказать, что покупка таких коров с подобным соотношением используемых пастбищ изменит баланс используемых пастбищ в стаде фермера.

# %%
df3.groupby('poroda_papy')['poroda_papy'].count()
# Out:
# poroda_papy
# Айдиал     4
# Соверин    7
# Name: poroda_papy, dtype: int64

# %%
df3.groupby('poroda_papy')['poroda_papy'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Порода папы коров Экофермы')
plt.show();

# %%
ax = df1['poroda_papy'].hist(alpha=0.5, bins=3, figsize=(5,6))
ax.set_ylabel('Количество коров')
ax.set_xlabel('Породы');
ax.set_title('Породы папы коров в стаде и на Экоферме');


ax = df3['poroda_papy'].hist(alpha=0.7, bins=3)
plt.legend(['Коровы в стаде', 'Коровы на Экоферме']);
plt.show()

# %% [markdown]
# Видим, что и в стаде, и на Экоферме чаще встречалась порода папы Соверин и реже - Айдиал.

# %%
ax = df2['imya_papy'].hist(figsize=(5,4))
ax = df3['umya_papy'].hist(figsize=(5,4))
plt.legend(['Коровы в стаде', 'Коровы на Экоферме']);
ax.set_title('Папы коров в стаде и на экоферме');

plt.show();

# %%
df2.groupby('imya_papy')['imya_papy'].count().sort_values()
# Out:
# imya_papy
# Геркулес     64
# Соловчик    110
# Буйный      215
# Барин       240
# Name: imya_papy, dtype: int64

# %%
df3.groupby('umya_papy')['umya_papy'].count().sort_values()
# Out:
# umya_papy
# Соловчик    1
# Барин       2
# Геркулес    3
# Буйный      5
# Name: umya_papy, dtype: int64

# %% [markdown]
# Видим, что в стаде и на Экоферме соотношение пап коров не совпадает: в стаде самый популярный папа - Барин, а на Экоферме - Буйный. Самый редкий для стада папа - Геркулес, а для фермы - Соловчик.

# %%
df3['tek_zhirnost'].unique()
# Out:
# array([3.])

# %% [markdown]
# В Экоферме жирность составляет 3%. В стаде фермера молоко (очень редко) бывает жирностью 2%.

# %%
df3['tek_belok'].unique()
# Out:
# array([3.])

# %% [markdown]
# В Экоферме белок в молоке составляет 3%, в стаде тоже, что снова вызывает вопросы о целесообразности столбца с данными о содержании белка.

# %%
df3.groupby('vozrast')['vozrast'].count()
# Out:
# vozrast
# более_2_лет    7
# менее_2_лет    4
# Name: vozrast, dtype: int64

# %%
df3.groupby('vozrast')['vozrast'].count().plot(kind='barh', figsize=(4,4), ylabel='', title='Возраст коров Экофермы')
plt.show();

# %%
ax = df1['vozrast'].hist(figsize=(5,4))
ax = df3['vozrast'].hist(figsize=(5,4))
plt.legend(['Коровы в стаде', 'Коровы на Экоферме']);
ax.set_title('Возраст коров в стаде и на Экоферме');

plt.show();

# %%
len(df1[df1['vozrast']=='более_2_лет']) / len(df1[df1['vozrast']!='более_2_лет'])
# Out:
# 5.4021739130434785

# %%
len(df3[df3['vozrast']=='более_2_лет']) / len(df3[df3['vozrast']!='более_2_лет'])
# Out:
# 1.75

# %% [markdown]
# Мы видим, что коров старше 2 лет больше - и в стаде, и на ферме. В стаде этот перевес заметнее (коров старше 2 лет в пять раз больше), чем на Экоферме (менее чем в 2 раза).
#
# С одной стороны, возраст, выраженный двумя категориями (старше и младше определенного возраста), обречен на то, что большая (старшая) категория будет со временем закономерно увеличиваться, что и происходит в стаде фермера. С этой точки зрения коровы на Экоферме могут примкнуть к более старшей группе в ближайшем времени (мы не располагаем данными - теоретически им может исполниться 2 года и через месяц, и через 1 год 11 месяцев).
#
# С другой стороны, взрослеющее стадо фермера могло подвергнуться сокращению (за счет естественной смертности, продажи коров или за счет мясного производства), но этого не происходит (случайно или намеренно).

# %% [markdown]
# Промежуточный вывод:
#
# * мы ставим под сомнение полезность столбца с данными о белке, который всегда равен 3%. Почти такая же ситуация с жирностью - крайне редко она достигает 2% (менее чем в 1% случаев), во всех остальных случаях она составляет 3%.
#
# * подозрительные экстремальные значения были удалены на этапе предобработки, но остались просто редкие значения (например, 2% жирности молока). Но эти данные не вызывают подозрений в правдивости, жирность может быть равной 2 процентам, поэтому мы решили оставить редкие значения.
#
# * в стаде фермера удой молока колеблется от 5204 до 7222 кг, среднее значение составляет 6159 кг, а медианное - 6171. СПО колеблется от 0.84 до 0.96, среднее значение - 0.91, медианное - 0.93. ЭКЕ колеблется от 10 до 16, среднее и медианное значения очень близки - 14 и 14.127. Сырой протеин колеблется от 1660 до 2349, среднее значение - 1929, медианное - 1901.
#
# * Мы видим, что в данных о коровах с Экофермы и в данных о коровах в стаде наблюдаются несовпадающие тенденции. В частности, в стаде фермера чаще встречаются другие породы, другие папы коров и другие пастбища. С этой точки зрения потенцально купленные на Экоферме коровы будут отличаться от самых распространенных коров стада.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Данные во всех трех датафреймах исследованы и предобработаны правильно. Молодец!

# %% [markdown]
# Шаг 4.Корреляционный анализ признаков.

# %% [markdown]
# Рассчитаем коэффициент корреляции между всеми признаками:

# %%
df1['udoy, kg'].corr(df1['spo'])
# Out:
# 0.806544056088634

# %%
df1['udoy, kg'].corr(df1['eke'])
# Out:
# 0.733053557474758

# %%
df1['udoy, kg'].corr(df1['syroy_protein'])
# Out:
# 0.433337745420685

# %%
df1['udoy, kg'].corr(df1['zhirnost, %'])
# Out:
# 0.09218813360229551

# %%
df1['udoy, kg'].corr(df1['belok, %'])
# Out:
# nan

# %%
df1['spo'].corr(df1['eke'])
# Out:
# 0.7312814048814413

# %%
df1['spo'].corr(df1['syroy_protein'])
# Out:
# 0.4406484046915747

# %%
df1['spo'].corr(df1['zhirnost, %'])
# Out:
# 0.11928660521921557

# %%
df1['syroy_protein'].corr(df1['zhirnost, %'])
# Out:
# 0.05938714584313737

# %% [markdown]
# По коэффициентам мы видим, что существует заметная корреляция между удоем и ЭКЕ, а также удоем и СПО (между целевым признаком и входными).
#
# С другой стороны, есть заметная корреляция между ЭКЕ и СПО, а это уже два входных признака, и в их корреляции кроется проблема для создания модели. Мультиколлинеарность признаков говорит об их взаимозависимости, а это значит, что модель не сможет решать поставленные задачи. Вероятно, один из взаимосвязанных признаков придется удалить.

# %%
pd.plotting.scatter_matrix(df1, figsize=(12,12))
plt.suptitle('Матрица рассеяния: удой, СПО, ЭКЕ, сырой протеин, порода, жирность, белок')
plt.show();

# %% [markdown]
# По матрице рассеяния мы видим зависимость удоя от СПО и ЭКЕ (зависимость между СПО и ЭКЕ тоже видна).
#
# Опираясь на открытые источники, можно предположить, что зависимость между СПО И ЭКЕ оправдана. Чем больше углеводов в сахарно-протеиновом (углеводно-белковом) соотношении, тем больше может возрастать энергетическая кормовая единица (при окислении белков и углеводов выделяется одинаковое количество энергии, но именно углеводы являются основным энергетическим материалом).

# %% [markdown]
# Поищем взаимосвязи между количественными (ЭКЕ, СПО, сырой протеин и удой) и категориальными данными (возраст в данном случае, порода, вкус, порода папы, тип пастбища).
# Исключим из анализа данные о содержании белка и жирности (белок всегда одинаковый, жирность почти всегда).

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['eke'], hue=df1['poroda'])
plt.title('Взаимосвязь данных: удой, ЭКЕ, порода')
plt.ylabel('ЭКЕ')
plt.xlabel('Удой, кг')
plt.show();

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['eke'], hue=df1['vozrast'])
plt.title('Взаимосвязь данных: удой, ЭКЕ, возраст')
plt.ylabel('ЭКЕ')
plt.xlabel('Удой, кг')
plt.show();

# %% [markdown]
# По графику видно, что коровы моложе 2 лет практически не дают большой удой. У них к тому же ниже ЭКЕ, что, возможно, отражается на стоимости их содержания, но фермер не ставил задачу оценить рентабельность коров, целевые признаки - удой и вкус.

# %%
df1.groupby('vozrast')['udoy, kg'].mean()
# Out:
# vozrast
# более_2_лет    6291.350101
# менее_2_лет    5447.097826
# Name: udoy, kg, dtype: float64

# %%
df1.groupby('vozrast')['udoy, kg'].median()
# Out:
# vozrast
# более_2_лет    6288.0
# менее_2_лет    5440.0
# Name: udoy, kg, dtype: float64

# %% [markdown]
# Видим, что молодые коровы дают меньше удоя, чем зрелые.

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['eke'], hue=df1['pastbische'])
plt.title('Взаимосвязь данных: удой, ЭКЕ, тип пастбища')
plt.ylabel('ЭКЕ')
plt.xlabel('Удой, кг')
plt.show();

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['eke'], hue=df1['vkus'])
plt.title('Взаимосвязь данных: удой, ЭКЕ, вкус')
plt.ylabel('ЭКЕ')
plt.xlabel('Удой, кг')
plt.show();

# %% [markdown]
# Похоже, на корме с высоким ЭКЕ вкус молока лучше.

# %%
df1.groupby('vkus')['eke'].mean()
# Out:
# vkus
# вкусно       14.368876
# не вкусно    13.780992
# Name: eke, dtype: float64

# %% [markdown]
# В среднем у коров, дающих вкусное молоко, корм с высоким ЭКЕ.

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['eke'], hue=df1['poroda_papy'])
plt.title('Взаимосвязь данных: удой, ЭКЕ, порода папы')
plt.ylabel('ЭКЕ')
plt.xlabel('Удой, кг')
plt.show();

# %% [markdown]
# Видим, что коровы, папы которых принадлежали к породе Айдиал, дают больше удоя, чем коровы с папой породы Соверин.

# %%
df1.groupby('poroda_papy')['udoy, kg'].mean()
# Out:
# poroda_papy
# Айдиал     6385.451049
# Соверин    5946.188119
# Name: udoy, kg, dtype: float64

# %% [markdown]
# В среднем коровы с папой породы Айдиал действительно дают больше молока.

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['spo'], hue=df1['poroda_papy'])
plt.title('Взаимосвязь данных: удой, СПО, порода папы')
plt.ylabel('СПО')
plt.xlabel('Удой, кг')

plt.show();

# %% [markdown]
# Получается, что коровы на корме с СПО менее 0.9 не дают более 6000 удоя, а с СПО более 0.9  дают больше 6000.

# %%
df1[(df1['spo']<0.9)&(df1['udoy, kg']>=6000)]
# Out:
# Empty DataFrame
# Columns: [id, udoy, kg, vozrast, spo, eke, syroy_protein, vkus, poroda, pastbische, poroda_papy, zhirnost, %, belok, %]
# Index: []

# %% [markdown]
# Получается, для достижения высокого удоя СПО должен быть больше 0.9.

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['spo'], hue=df1['vkus'])
plt.title('Взаимосвязь данных: удой, СПО, вкус')
plt.ylabel('СПО')
plt.xlabel('Удой, кг')
plt.show();

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['spo'], hue=df1['pastbische'])
plt.title('Взаимосвязь данных: удой, СПО, тип пастбища')
plt.ylabel('СПО')
plt.xlabel('Удой, кг')
plt.show();

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['spo'], hue=df1['vozrast'])
plt.title('Взаимосвязь данных: удой, СПО, возраст')
plt.ylabel('СПО')
plt.xlabel('Удой, кг')
plt.show();

# %% [markdown]
# Видим, что коровы моложе 2 лет практически не получают СПО более 0.9.

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['spo'], hue=df1['poroda'])
plt.title('Взаимосвязь данных: удой, СПО, порода')
plt.ylabel('СПО')
plt.xlabel('Удой, кг')
plt.show();

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['syroy_protein'], hue=df1['poroda_papy'])
plt.title('Взаимосвязь данных: удой, сырой протеин, порода папы')
plt.ylabel('Сырой протеин')
plt.xlabel('Удой, кг')
plt.show();

# %% [markdown]
# Видим, что коровы с папой породы Айдиал едят корм с большим количеством сырого протеина.

# %%
df1.groupby('poroda_papy')['syroy_protein'].mean()
# Out:
# poroda_papy
# Айдиал     1934.370629
# Соверин    1925.729373
# Name: syroy_protein, dtype: float64

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['syroy_protein'], hue=df1['poroda'])
plt.title('Взаимосвязь данных: удой, сырой протеин, порода')
plt.ylabel('Сырой протеин')
plt.xlabel('Удой, кг')
plt.show();

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['syroy_protein'], hue=df1['vozrast'])
plt.title('Взаимосвязь данных: удой, сырой протеин, возраст')
plt.ylabel('Сырой протеин')
plt.xlabel('Удой, кг')
plt.show();

# %% [markdown]
# Опять видим, что старшие коровы дают больше молока, дополнительный факт - молодые коровы практически не употребляют корм с содержанием сырого протеина выше 2000 (возможно, это отражается на стоимости их содержания).

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['syroy_protein'], hue=df1['pastbische'])
plt.title('Взаимосвязь данных: удой, сырой протеин, тип пастбища')
plt.ylabel('Сырой протеин')
plt.xlabel('Удой, кг')
plt.show();

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['syroy_protein'], hue=df1['vkus'])
plt.title('Взаимосвязь данных: удой, сырой протеин, вкус')
plt.ylabel('Сырой протеин')
plt.xlabel('Удой, кг')
plt.show();

# %%
sns.scatterplot(x=df1['eke'], y=df1['spo'], hue=df1['vozrast'])
plt.title('Взаимосвязь данных: ЭКЕ, СПО, возраст')
plt.ylabel('СПО')
plt.xlabel('ЭКЕ')
plt.show();

# %% [markdown]
# Видим, что есть определенная взаимосвязь между входными признаками СПО и ЭКЕ: при ЭКЕ менее 13 СПО не поднимается выше 0.9, а при СПО выше 0.9 ЭКЕ не опускается ниже 13. Как было видно в процессе исследования, низкие СПО и ЭКЕ у корма для молодых коров.

# %%
sns.scatterplot(x=df1['eke'], y=df1['spo'], hue=df1['vkus'])
plt.title('Взаимосвязь данных: ЭКЕ, СПО, вкус')
plt.ylabel('СПО')
plt.xlabel('ЭКЕ')
plt.show();

# %% [markdown]
# Видим, что молоко с высоким СПО И ЭКЕ более вкусное. Проверим:

# %%
len(df1[(df1['spo']<0.9)&(df1['vkus']=='вкусно')]) / len(df1[(df1['spo']<0.9)])
# Out:
# 0.5342465753424658

# %%
len(df1[(df1['spo']>0.9)&(df1['vkus']=='вкусно')]) / len(df1[(df1['spo']>0.9)])
# Out:
# 0.6216216216216216

# %% [markdown]
# Видим, что молоко с СПО выше 0.9 чаще бывает вкусным, но разница в показателях менее 10%.

# %% [markdown]
# Промежуточные выводы:

# %% [markdown]
# В результате исследования мы выявили следующие особенности данных:
#
#
#
#
# * Существует заметная положительная корреляция между удоем и ЭКЕ, а также удоем и СПО (0.8 и 0.7 соответственно).
#
# * Удой выше 6000 - только у коров, в чьем корме СПО выше 0.9.
#
# * Коровы моложе 2 лет в среднем характеризуются меньшим удоем, чем коровы старше 2 лет.
#
# * Молодые коровы получают корм с низким СПО и ЭКЕ - коровы моложе 2 лет практически не получают СПО более 0.9.
#
# * Коровы на корме с высоким СПО И ЭКЕ чаще дают вкусное молоко.
#
# * При ЭКЕ менее 13 СПО не поднимается выше 0.9, а при СПО выше 0.9 ЭКЕ не опускается ниже 13.
#
# * Молодые коровы практически не употребляют корм с содержанием сырого протеина выше 2000.
#
# * Коровы с папой породы Айдиал едят корм с большим количеством сырого протеина и дают больше удоя, чем коровы с папой породы Соверин.
#
# * Видим нелинейные взаимосвязи некоторых входных и целевого признаков. Признак СПО в зависимости от удоя делится на два интервала: до 0.9 и выше 0.92. В связи с этим на следующем этапе работы он будет преобразован в категориальный.
#
# * Признак ЭКЕ тоже связан с целевым признаком нелинейно: график похож на часть изогнутой параболы. В связи с этим на следующем этапе работы ЭКЕ будет возведен в квадрат.
#
#
# Однако мы заметили, что некоторые входные признаки (СПО и ЭКЕ) тоже взаимозависимы -  коэффициент корреляции 0.7.
# При ЭКЕ менее 13 СПО не поднимается выше 0.9, а при СПО выше 0.9 ЭКЕ не опускается ниже 13. Это говорит о мультиколлинеарности данных и потенциальной необходимости убрать один из взаимозависимых входных признаков из анализа.
#
# Есть взаимосвязь между возрастом, удоем и СПО - чем старше корова, тем выше СПО и выше удой.
#
# Есть взаимосвязь породы папы, употреблением сырого протеина и удоем - коровы с папой-Айдиалом употребляют больше сырого протеина и дают больше молока.
#
# Показатели СПО разделяются на две принципиальные группы -  до 0.9 и выше 0.9 (по взаимодействию с целевым признаком).
#
#
# Есть причины исключить из корреляционного анализа данные о содержании белка и жирности (белок всегда одинаковый, жирность почти всегда).
#
# В связи с тем, что коровы разного возраста и разных пород не только дают разный удой и молоко разного качества, но и содержатся в очевидно разных условиях, то, возможно, стоит подумать, не стоит ли их содержание дороже упущенной выгоды от низкого удоя или менее вкусного молока. Однако поскольку данная задача не поставлена фермером, мы сконцентрируемся на других.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1<a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>   Отметь, пожалуйста, есть ли нелинейная связь между признаками. Для ответа на этот вопрос тебе нужно внимаательно изучить зависимости на графиках.

# %% [markdown]
#
# <div class="alert alert-info">
# <b>Спасибо, добавила два последних пункта про нелинейные зависимости между входными признаками и целевым!</b>
# </div>

# %% [markdown]
# Шаг 5. Задача регрессии.

# %% [markdown]
# 1. Создаем модель линейной регрессии. Для построения модели отбираем в качестве целевого признака:
# * удой,
#
# а в качестве входных -
#
# * ЭКЕ,
# * сырой протеин,
# * породу,
# * тип пастбища,
# * породу папы.
#
#   СПО не берем, потому что этот признак оказался взаимозависим от других (возраста, ЭКЕ).
#   Жирность и белок не берем, потому что они почти всегда одинаковые.
#   Вкус не берем, потому что это тоже целевой признак в дальнейшем.

# %%
df_m = df1[['udoy, kg', 'eke', 'syroy_protein', 'vozrast', 'poroda', 'pastbische', 'poroda_papy']]
X = df_m.drop('udoy, kg' , axis=1)
y = df_m['udoy, kg']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state = RANDOM_STATE)

cat_col_names = ['vozrast', 'poroda', 'pastbische', 'poroda_papy']

num_col_names = ['eke', 'syroy_protein']


encoder = OneHotEncoder(sparse_output=False, drop='first')

X_train_ohe = encoder.fit_transform(X_train[cat_col_names])

X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names_out()


scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[num_col_names])

X_test_scaled = scaler.transform(X_test[num_col_names])


X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)

X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)


X_train_scaled = pd.DataFrame(X_train_scaled, columns = num_col_names)

X_test_scaled = pd.DataFrame(X_test_scaled, columns = num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)

X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)


model_lr = LinearRegression()
model_lr.fit(X_train, y_train)

predictions = model_lr.predict(X_test)

residuals = y_test - predictions


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(residuals)
axes[0].set_title('Гистограмма распределения остатков')
axes[0].set_xlabel('Остатки')
axes[1].scatter(predictions, residuals)
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
axes[1].set_title('Анализ дисперсии')
plt.show()

mse = mean_squared_error(predictions, y_test)
print(mse)
rmse  = np.sqrt(mean_squared_error(predictions, y_test))
print(rmse)
mae = mean_absolute_error(y_test, predictions)
mae
# Out:
# 53803.922406070466
# 231.95672528743475
# 185.35155403241035

# %%
r2 = r2_score(y_test, predictions)
r2
# Out:
# 0.745284194289008

# %% [markdown]
# По гистограмме распределения остатков видим, что самые популярные зачения смещены влево - это значит, что модель чаще занижает целевой признак. В таком случае фермер не купит корову, которая могла бы ему подойти.
#
# По анализу дисперсии видно, что больше всего ошибок модель совершает в районе значений удоя 6000-6250.
# Проблем с выбросами нет. Бимодальности распределения тоже нет.
#
# Это значит, что для улучшения работы модели стоит трансформировать ее признаки (перевести числовой признак в категориальный, например).
#
# R2 равно 0.74  - это значит, что в 74 процентах модель предсказывает результат лучше среднего значения, однако в 26% процентах случаях она ошибается сильнее, чем среднее значение целевого признака.

# %% [markdown]
# 2. Создаем новую модель линейной регрессии, включаем в нее СПО. Для того, чтобы исключить нелинейность связи СПО и удоя, переводим СПО в бинарный признак. По диаграмме рассеяния мы видим, что принципиальные различия лежать по границе значения 0.9.

# %%
def cluster_func(row):
    spo = row['spo']
    if spo>=0.9:
        return 2
    else:
        return 1
    
df1['cluster'] = df1.apply(cluster_func, axis=1)

# %% [markdown]
# Чтобы сделать зависимость ЭКЕ и удоя линейной, создаем новый столбец - ЭКЕ в квадрате.

# %%
df1['eke_2'] = df1['eke']**2

# %%
df1.head()
# Out:
#     id  udoy, kg      vozrast   spo   eke  syroy_protein    vkus  \
# 0    1    5863.0  более_2_лет  0.89  14.0         1743.0  вкусно
# 1    2    5529.0  менее_2_лет  0.89  12.0         2138.0  вкусно
# 7    8    6179.0  более_2_лет  0.93  14.0         1806.0  вкусно
# 8    9    6783.0  более_2_лет  0.94  14.0         1918.0  вкусно
# 11  12    6563.0  более_2_лет  0.93  16.0         2328.0  вкусно
#
#              poroda pastbische poroda_papy  zhirnost, %  belok, %  cluster  \
# 0    Вис Бик Айдиал  равнинное      Айдиал          3.0       3.0        1
# 1    Вис Бик Айдиал  равнинное     Соверин          3.0       3.0        1
# 7    Вис Бик Айдиал  равнинное      Айдиал          3.0       3.0        2
# 8   РефлешнСоверинг  холмистое      Айдиал          3.0       3.0        2
# 11   Вис Бик Айдиал  холмистое     Соверин          3.0       3.0        2
#
#     eke_2
# 0   196.0
# 1   144.0
# 7   196.0
# 8   196.0
# 11  256.0

# %%
df_m2 = df1[['udoy, kg', 'eke_2', 'syroy_protein', 'vozrast', 'poroda', 'pastbische', 'poroda_papy', 'cluster']]

X = df_m2.drop('udoy, kg' , axis=1)
y = df_m2['udoy, kg']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state = RANDOM_STATE)


cat_col_names = ['vozrast',  'poroda', 'pastbische', 'poroda_papy', 'cluster']

num_col_names = ['eke_2', 'syroy_protein']


encoder = OneHotEncoder(sparse_output=False, drop='first')

X_train_ohe = encoder.fit_transform(X_train[cat_col_names])

X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names_out()


scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[num_col_names])

X_test_scaled = scaler.transform(X_test[num_col_names])


X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)

X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)


X_train_scaled = pd.DataFrame(X_train_scaled, columns = num_col_names)

X_test_scaled = pd.DataFrame(X_test_scaled, columns = num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)

X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

model_lr = LinearRegression()
model_lr.fit(X_train, y_train)

predictions = model_lr.predict(X_test)

residuals = y_test - predictions


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(residuals)
axes[0].set_title('Гистограмма распределения остатков')
axes[0].set_xlabel('Остатки')
axes[1].scatter(predictions, residuals)
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
axes[1].set_title('Анализ дисперсии')
plt.show()


mse = mean_squared_error(predictions, y_test)
print(mse)
rmse  = np.sqrt(mean_squared_error(predictions, y_test))
print(rmse)
mae = mean_absolute_error(y_test, predictions)
print(mae)
r2 = r2_score(y_test, predictions)
r2
# Out:
# 37671.13806889861
# 194.09054090526567
# 154.25346914251847
# 0.8216592051997511

# %% [markdown]
# Видим, что пик значений остатков на -200 -  модель занижает показатели удоя. R2 остался на том же уровне. Выбросов и бимодальности нет, однако дисперсия неоднородная.

# %% [markdown]
# 3. Создаем третью модель.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         629 non-null    int64
#  1   imya_papy  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB

# %%
df1 = pd.merge(df1, df2, on='id', how='left')

# %%
sns.scatterplot(x=df1['udoy, kg'], y=df1['syroy_protein'], hue=df1['imya_papy'])
plt.title('Взаимосвязь данных: удой, сырой протеин, тип пастбища')
plt.ylabel('Сырой протеин')
plt.xlabel('Удой, кг')
plt.show();

# %% [markdown]
# Видим, что дети Буйного и Геркулеса (Айдиал) дают больше удоя, чем дети Соловчика и Барина (Соверин).

# %%
df_m3 = df1[['udoy, kg', 'eke_2', 'syroy_protein', 'vozrast', 'poroda', 'pastbische', 'poroda_papy', 'cluster', 'imya_papy']]

X = df_m3.drop('udoy, kg' , axis=1)
y = df_m3['udoy, kg']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state = RANDOM_STATE)


cat_col_names = ['vozrast', 'poroda', 'pastbische', 'poroda_papy', 'cluster', 'imya_papy']

num_col_names = ['eke_2', 'syroy_protein']


encoder = OneHotEncoder(sparse_output=False, drop='first')

X_train_ohe = encoder.fit_transform(X_train[cat_col_names])

X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names_out()


scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[num_col_names])

X_test_scaled = scaler.transform(X_test[num_col_names])


X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)

X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)


X_train_scaled = pd.DataFrame(X_train_scaled, columns = num_col_names)

X_test_scaled = pd.DataFrame(X_test_scaled, columns = num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)

X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

model_lr = LinearRegression()
model_lr.fit(X_train, y_train)

predictions = model_lr.predict(X_test)

residuals = y_test - predictions


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(residuals)
axes[0].set_title('Гистограмма распределения остатков')
axes[0].set_xlabel('Остатки')
axes[1].scatter(predictions, residuals)
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
axes[1].set_title('Анализ дисперсии')
plt.show()

mse = mean_squared_error(predictions, y_test)
print(mse)
rmse  = np.sqrt(mean_squared_error(predictions, y_test))
print(rmse)
mae = mean_absolute_error(y_test, predictions)
mae
# Out:
# 38362.22591312968
# 195.86277316817936
# 156.97520831904552

# %%
r2 = r2_score(y_test, predictions)
r2
# Out:
# 0.8183874921128902

# %% [markdown]
# Многочисленные пики, неравномерная дисперсия.
#
# Попробуем убрать из признаков породу папы - этот признак связан с признаком имени папы, и они точно между собой связаны (два входных признака).

# %%
df_m3 = df1[['udoy, kg', 'eke_2', 'vozrast','syroy_protein',  'poroda', 'pastbische', 'cluster', 'imya_papy']]

X = df_m3.drop('udoy, kg' , axis=1)
y = df_m3['udoy, kg']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state = RANDOM_STATE)


cat_col_names = ['vozrast', 'poroda', 'pastbische', 'cluster', 'imya_papy']

num_col_names = ['eke_2','syroy_protein']


encoder = OneHotEncoder(sparse_output=False, drop='first')

X_train_ohe = encoder.fit_transform(X_train[cat_col_names])

X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names_out()


scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[num_col_names])

X_test_scaled = scaler.transform(X_test[num_col_names])


X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)

X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)


X_train_scaled = pd.DataFrame(X_train_scaled, columns = num_col_names)

X_test_scaled = pd.DataFrame(X_test_scaled, columns = num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)

X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

model_lr = LinearRegression()
model_lr.fit(X_train, y_train)

predictions = model_lr.predict(X_test)

residuals = y_test - predictions


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(residuals)
axes[0].set_title('Гистограмма распределения остатков')
axes[0].set_xlabel('Остатки')
axes[1].scatter(predictions, residuals)
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
axes[1].set_title('Анализ дисперсии')
plt.show()

mse = mean_squared_error(predictions, y_test)
print(mse)
rmse  = np.sqrt(mean_squared_error(predictions, y_test))
print(rmse)
mae = mean_absolute_error(y_test, predictions)
mae
# Out:
# 38202.76180169245
# 195.4552680325922
# 156.5186080302915

# %%
r2 = r2_score(y_test, predictions)
r2
# Out:
# 0.819142419036622

# %% [markdown]
# Проблемы с пиками остатков и дисперсией не удалось решить.

# %% [markdown]
# 4. Промежуточные выводы:
#
# Третью модель лучше не использовать из-за многочисленных пиков и неоднородной дисперсии. R2 в моделях одинаковый.

# %% [markdown]
# 5. Оценим модели с точки зрения метрик MSE, RMSE и MAE.
#
# В данных нет больших выбросов, поэтому можно воспользоваться любой из метрик.
#
# В первой модели:
# MSE =53803
# RMSE = 231
# MAE = 185
#
# Во второй модели:
# MSE = 53180
# RMSE = 230
# MAE = 183
#
# В третьей модели:
# MSE = 53358
# RMSE = 230
# MAE = 185
#
# Мы видим, что у второй модели самые низкие показатели метрик, будем работать с ней.

# %% [markdown]
# 6. Посчитаем доверительный интервал и квантили ошибок второй модели.

# %%
df_m2 = df1[['udoy, kg', 'eke_2', 'syroy_protein', 'vozrast', 'poroda', 'pastbische', 'poroda_papy', 'cluster']]

X = df_m2.drop('udoy, kg' , axis=1)
y = df_m2['udoy, kg']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state = RANDOM_STATE)


cat_col_names = ['vozrast',  'poroda', 'pastbische', 'poroda_papy', 'cluster']

num_col_names = ['eke_2', 'syroy_protein']


encoder = OneHotEncoder(sparse_output=False, drop='first')

X_train_ohe = encoder.fit_transform(X_train[cat_col_names])

X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names_out()


scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[num_col_names])

X_test_scaled = scaler.transform(X_test[num_col_names])


X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)

X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)


X_train_scaled = pd.DataFrame(X_train_scaled, columns = num_col_names)

X_test_scaled = pd.DataFrame(X_test_scaled, columns = num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)

X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

model_lr = LinearRegression()
model_lr.fit(X_train, y_train)

predictions = model_lr.predict(X_test)

residuals = y_test - predictions

# %%
pred_mean = predictions.mean()
pred_mean
# Out:
# 6124.551418042103

# %%
pred_std = predictions.std()
pred_std
# Out:
# 405.19572217200505

# %%
confidence_level = 0.95

# %%
z_score = 1.96

# %%
len(predictions)
# Out:
# 148

# %%
margin_of_error = z_score*(predictions.std() / np.sqrt(len(predictions)))
margin_of_error
# Out:
# 65.28149105782973

# %%
confidence_interval_high = pred_mean + margin_of_error
confidence_interval_low = pred_mean - margin_of_error

# %%
plt.hist(predictions, bins=20, color='skyblue')
plt.axvline(confidence_interval_low, color='red', label='Нижняя граница')
plt.axvline(confidence_interval_high, color='red', label='Верхняя граница')

plt.axvline(pred_mean, color='black', label='Среднее значение')
plt.xlabel('Предсказанные значения')
plt.ylabel('Частота')
plt.title('Доверительный интервал с 95% вероятностью')
plt.legend()
plt.show();

# %% [markdown]
# 6. Спрогнозируем удой коров, которых хочет купить фермер.

# %%
df3['eke'] = df1['eke'].mean()*1.05

# %%
df3['syroy_protein'] = df1['syroy_protein'].mean()*1.05

# %%
df3['spo']= df1['spo'].mean()*1.05

# %%
df3.head(2)
# Out:
#            poroda pastbische poroda_papy umya_papy  tek_zhirnost  tek_belok  \
# 0  Вис Бик Айдиал  холмистое      Айдиал  Геркулес           3.0        3.0
# 1  Вис Бик Айдиал  равнинное     Соверин    Буйный           3.0        3.0
#
#        vozrast        eke  syroy_protein      spo
# 0  более_2_лет  14.833701    2026.421562  0.96026
# 1  менее_2_лет  14.833701    2026.421562  0.96026

# %%
def cluster_func(row):
    spo = row['spo']
    if spo>=0.9:
        return 2
    else:
        return 1
    
df3['cluster'] = df3.apply(cluster_func, axis=1)

# %%
df3['eke_2'] = df3['eke']**2

# %%
df3.head(2)
# Out:
#            poroda pastbische poroda_papy umya_papy  tek_zhirnost  tek_belok  \
# 0  Вис Бик Айдиал  холмистое      Айдиал  Геркулес           3.0        3.0
# 1  Вис Бик Айдиал  равнинное     Соверин    Буйный           3.0        3.0
#
#        vozrast        eke  syroy_protein      spo  cluster       eke_2
# 0  более_2_лет  14.833701    2026.421562  0.96026        2  220.038691
# 1  менее_2_лет  14.833701    2026.421562  0.96026        2  220.038691

# %%
X_test_ohe = encoder.transform(df3[cat_col_names])

encoder_col_names = encoder.get_feature_names_out()


X_test_scaled = scaler.transform(df3[num_col_names])



X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)


X_test_scaled = pd.DataFrame(X_test_scaled, columns = num_col_names)


X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

predictions2 = model_lr.predict(X_test)

# %%
predictions2
# Out:
# array([6551.82229393, 6077.41249939, 6316.85966835, 6578.45053722,
#        6547.01088621, 6104.04074268, 6290.23142506, 6365.63161154,
#        6321.67107607, 6316.85966835, 6108.8521504 ])

# %% [markdown]
# По прогнозу данной модели все коровы получат удой выше 6000.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Задача линейной регрессии решена верно, хвалю! Каждяа из 3 моделей улучшает предыдущую, что показывает, что новыее признаки полезны. Молодец!

# %% [markdown]
# Шаг 6. Задача классификации.
#
# Создаем модель логистической регрессии для прогноза вкуса молока (целевой признак).
#
# Добавляем входные признаки:
# *  возраст,
# * СПО (кластеры)
# * ЭКЕ (в квадрате)
# * сырой протеин
# * пастбище
# * порода папы
#
# Удой и породу папы убрали из входных признаков, когда экспериментально увидели, что от этого растет accuracy. Вероятно, это связано с тем, что порода папы коррелирует с породой коровы.

# %%
df_ml = df1[['eke_2', 'syroy_protein', 'pastbische',  'vkus', 'poroda_papy', 'vozrast',]]

X = df_ml.drop('vkus' , axis=1)
y = df_ml['vkus']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state = RANDOM_STATE)


cat_col_names = [ 'vozrast', 'pastbische', 'poroda_papy']

num_col_names = ['eke_2', 'syroy_protein']


encoder = OneHotEncoder(sparse_output=False, drop='first')

X_train_ohe = encoder.fit_transform(X_train[cat_col_names])

X_test_ohe = encoder.transform(X_test[cat_col_names])

encoder_col_names = encoder.get_feature_names_out()


scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train[num_col_names])

X_test_scaled = scaler.transform(X_test[num_col_names])


X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)

X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)


X_train_scaled = pd.DataFrame(X_train_scaled, columns = num_col_names)

X_test_scaled = pd.DataFrame(X_test_scaled, columns = num_col_names)

X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)

X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

clf = LogisticRegression()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.6418918918918919

# %% [markdown]
# На данный момент видим, что модель нуждается в улучшении, которого мы рассчитываем добиться в будущем.

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True);
plt.xlabel('Предсказанные значения')
plt.ylabel('Истинные значения')
plt.show()

# %% [markdown]
# Видим 15 ошибок false positive, которые нужно минимизировать - для фермера важно вкусное молоко, иначе его никто не купит.
#
# Видим 38 ошибок false negative, это тоже стоило бы улучшить, но они не кажутся такими критичными - в этом случае фермер не купит корову с вкусным молоком.
#
# Исходя из этого нам важнее метрика precision.

# %%
y_proba = clf.predict_proba(X_test)

# %%
y_proba
# Out:
# array([[0.29279058, 0.70720942],
#        [0.71686014, 0.28313986],
#        [0.50898249, 0.49101751],
#        [0.80008818, 0.19991182],
#        [0.60250861, 0.39749139],
#        [0.67885709, 0.32114291],
#        [0.69722488, 0.30277512],
#        [0.53339612, 0.46660388],
#        [0.30483375, 0.69516625],
#        [0.34983082, 0.65016918],
#        [0.45007728, 0.54992272],
#        [0.68153739, 0.31846261],
#        [0.57947217, 0.42052783],
#        [0.59096729, 0.40903271],
#        [0.45399182, 0.54600818],
#        [0.72394971, 0.27605029],
#        [0.70549981, 0.29450019],
#        [0.5380613 , 0.4619387 ],
#        [0.6219283 , 0.3780717 ],
#        [0.79403345, 0.20596655],
#        [0.60545863, 0.39454137],
#        [0.4281425 , 0.5718575 ],
#        [0.48068115, 0.51931885],
#        [0.6923334 , 0.3076666 ],
#        [0.41187   , 0.58813   ],
#        [0.7090527 , 0.2909473 ],
#        [0.46546169, 0.53453831],
#        [0.70130357, 0.29869643],
# ...

# %%
data = pd.DataFrame(zip(y_test, y_proba[:, 0]),
             columns = ['y_valid', 'y_proba']).sort_values(by='y_proba',ascending=False)

# %%
data.head(2)
# Out:
#    y_valid   y_proba
# 3   вкусно  0.800088
# 91  вкусно  0.796955

# %%
thresholds = [round(i,2) for i in np.linspace(0.1,1,num = 8,endpoint=False)]
thresholds
# Out:
# [0.1, 0.21, 0.32, 0.44, 0.55, 0.66, 0.78, 0.89]

# %%
columns = []
for i in thresholds:
	columns.append('y_pred_'+str(i))
	data['y_pred_'+str(i)] = data['y_proba'].apply(lambda x:1 if x>=i else 0)

# %%
def valid_func(row):
    y_val = row['y_valid']
    if y_val=='вкусно':
        return 1
    else:
        return 0
    
data['y_val'] = data.apply(valid_func, axis=1)

# %%
data.head(10)
# Out:
#        y_valid   y_proba  y_pred_0.1  y_pred_0.21  y_pred_0.32  y_pred_0.44  \
# 3       вкусно  0.800088           1            1            1            1
# 91      вкусно  0.796955           1            1            1            1
# 132     вкусно  0.795206           1            1            1            1
# 19      вкусно  0.794033           1            1            1            1
# 29      вкусно  0.776227           1            1            1            1
# 116  не вкусно  0.774866           1            1            1            1
# 92      вкусно  0.774489           1            1            1            1
# 107     вкусно  0.769813           1            1            1            1
# 101     вкусно  0.769503           1            1            1            1
# 69      вкусно  0.765056           1            1            1            1
#
#      y_pred_0.55  y_pred_0.66  y_pred_0.78  y_pred_0.89  y_val
# 3              1            1            1            0      1
# ...

# %%
precision = precision_score(data['y_val'], data['y_pred_0.55'])
precision
# Out:
# 0.6521739130434783

# %%
precision = precision_score(data['y_val'], data['y_pred_0.32'])
precision
# Out:
# 0.5845070422535211

# %%
precision = precision_score(data['y_val'], data['y_pred_0.78'])
precision
# Out:
# 1.0

# %%
precision = precision_score(data['y_val'], data['y_pred_0.66'])
precision
# Out:
# 0.8

# %%
recall = recall_score(data['y_val'], data['y_pred_0.66'])
print(recall)
# Out:
# 0.46511627906976744

# %%
recall = recall_score(data['y_val'], data['y_pred_0.78'])
print(recall)
# Out:
# 0.046511627906976744

# %%
y_pred = (clf.predict_proba(X_test)[:,1] >= 0.66)

# %%
y_pred
# Out:
# array([ True, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %% [markdown]
# Предлагаем выбрать параметр 0.66, чтобы  не только увеличить precision, но и метрика recall не сводилась к 4 процентам.

# %%
df_ml.head()
# Out:
#    eke_2  syroy_protein pastbische    vkus poroda_papy      vozrast
# 0  196.0         1743.0  равнинное  вкусно      Айдиал  более_2_лет
# 1  144.0         2138.0  равнинное  вкусно     Соверин  менее_2_лет
# 2  196.0         1806.0  равнинное  вкусно      Айдиал  более_2_лет
# 3  196.0         1918.0  холмистое  вкусно      Айдиал  более_2_лет
# 4  256.0         2328.0  холмистое  вкусно     Соверин  более_2_лет

# %%
df_ml_vkus = df3[['eke_2', 'syroy_protein', 'pastbische', 'poroda_papy', 'vozrast']]

# %%
df_ml_vkus.head(3)
# Out:
#         eke_2  syroy_protein pastbische poroda_papy      vozrast
# 0  220.038691    2026.421562  холмистое      Айдиал  более_2_лет
# 1  220.038691    2026.421562  равнинное     Соверин  менее_2_лет
# 2  220.038691    2026.421562  равнинное     Соверин  более_2_лет

# %%
df_ml_vkus_ohe = encoder.transform(df_ml_vkus[cat_col_names])
encoder_col_names = encoder.get_feature_names_out()

df_ml_vkus_scaled = scaler.transform(df_ml_vkus[num_col_names])

df_ml_vkus_ohe = pd.DataFrame(df_ml_vkus_ohe, columns=encoder_col_names)


df_ml_vkus_scaled = pd.DataFrame(df_ml_vkus_scaled, columns = num_col_names)

df_ml_vkus = pd.concat([df_ml_vkus_ohe, df_ml_vkus_scaled], axis=1)

y_pred = clf.predict(df_ml_vkus)

# %%
y_pred
# Out:
# array(['вкусно', 'не вкусно', 'вкусно', 'вкусно', 'вкусно', 'не вкусно',
#        'вкусно', 'вкусно', 'вкусно', 'вкусно', 'вкусно'], dtype=object)

# %%
y_pred1 = (clf.predict_proba(df_ml_vkus)[:,1] >= 0.66)

# %%
y_pred1
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
df3 = df3.reset_index(drop=True)

# %% [markdown]
# К сожалению, с такими данными мы не можем рекомендовать ни одну корову к покупке из-за вкуса молока. Стоит отметить, что с порогом 0.5 у фермера были варианты покупки, поэтому мы оставим оба варианта прогноза.

# %%
df3['udoy, kg'] = pd.DataFrame(predictions2)

# %%
df3
# Out:
#              poroda pastbische poroda_papy umya_papy  tek_zhirnost  tek_belok  \
# 0    Вис Бик Айдиал  холмистое      Айдиал  Геркулес           3.0        3.0
# 1    Вис Бик Айдиал  равнинное     Соверин    Буйный           3.0        3.0
# 2   РефлешнСоверинг  равнинное     Соверин     Барин           3.0        3.0
# 3   РефлешнСоверинг  холмистое      Айдиал    Буйный           3.0        3.0
# 4   РефлешнСоверинг  равнинное      Айдиал    Буйный           3.0        3.0
# 5   РефлешнСоверинг  равнинное     Соверин  Геркулес           3.0        3.0
# 6    Вис Бик Айдиал  равнинное     Соверин    Буйный           3.0        3.0
# 7   РефлешнСоверинг  холмистое      Айдиал    Буйный           3.0        3.0
# 8    Вис Бик Айдиал  холмистое     Соверин  Соловчик           3.0        3.0
# 9   РефлешнСоверинг  равнинное     Соверин  Геркулес           3.0        3.0
# 10   Вис Бик Айдиал  холмистое     Соверин     Барин           3.0        3.0
#
# ...

# %%
df3['vkus1'] = pd.DataFrame(y_pred)

# %%
df3['vkus2'] = pd.DataFrame(y_pred1)

# %%
df3.head()
# Out:
#             poroda pastbische poroda_papy umya_papy  tek_zhirnost  tek_belok  \
# 0   Вис Бик Айдиал  холмистое      Айдиал  Геркулес           3.0        3.0
# 1   Вис Бик Айдиал  равнинное     Соверин    Буйный           3.0        3.0
# 2  РефлешнСоверинг  равнинное     Соверин     Барин           3.0        3.0
# 3  РефлешнСоверинг  холмистое      Айдиал    Буйный           3.0        3.0
# 4  РефлешнСоверинг  равнинное      Айдиал    Буйный           3.0        3.0
#
#        vozrast        eke  syroy_protein      spo  cluster       eke_2  \
# 0  более_2_лет  14.833701    2026.421562  0.96026        2  220.038691
# 1  менее_2_лет  14.833701    2026.421562  0.96026        2  220.038691
# 2  более_2_лет  14.833701    2026.421562  0.96026        2  220.038691
# 3  более_2_лет  14.833701    2026.421562  0.96026        2  220.038691
# 4  более_2_лет  14.833701    2026.421562  0.96026        2  220.038691
#
#       udoy, kg      vkus1  vkus2
# 0  6551.822294     вкусно  False
# ...

# %% [markdown]
# Промежуточный итог:
#
# На данный момент мы видим, что модель логистической регрессии нуждается в улучшении, потому что метрики недостаточно высоки: accuracy 64%, после настройки метрики precision мы не смогли порекомендовать фермеру ни одну корову для покупки.
#
# На данный момент мы попробовали убирать входные признаки, которые коррелируют между собой (порода папы и имя папы), возводить в квадрат признаки и переводить количественный признак (СПО) в категориальный.
#
# Кроме этого, можно было бы вернуться к самому началу и уточнить, как именно должны (в значениях какого порядка) выглядеть показатели каждого признака и проверить, не допущена ли ошибка в предобработке данных (может быть, жирность или белок содержались в другом столбце).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Задача классификации также решена правильно. Молодец!

# %% [markdown]
# Шаг 7. Итоговые выводы.

# %% [markdown]
# После выставленного вручную критерия у нас не осталось коров, которых можно было порекомендовать к покупке. Однако при критерии 0.5 мы могли бы рекомендовать этих коров:

# %%
df3[(df3['udoy, kg']>6000)&(df3['vkus1']=='вкусно')]
# Out:
#              poroda pastbische poroda_papy umya_papy  tek_zhirnost  tek_belok  \
# 0    Вис Бик Айдиал  холмистое      Айдиал  Геркулес           3.0        3.0
# 2   РефлешнСоверинг  равнинное     Соверин     Барин           3.0        3.0
# 3   РефлешнСоверинг  холмистое      Айдиал    Буйный           3.0        3.0
# 4   РефлешнСоверинг  равнинное      Айдиал    Буйный           3.0        3.0
# 6    Вис Бик Айдиал  равнинное     Соверин    Буйный           3.0        3.0
# 7   РефлешнСоверинг  холмистое      Айдиал    Буйный           3.0        3.0
# 8    Вис Бик Айдиал  холмистое     Соверин  Соловчик           3.0        3.0
# 9   РефлешнСоверинг  равнинное     Соверин  Геркулес           3.0        3.0
# 10   Вис Бик Айдиал  холмистое     Соверин     Барин           3.0        3.0
#
#         vozrast        eke  syroy_protein      spo  cluster       eke_2  \
# 0   более_2_лет  14.833701    2026.421562  0.96026        2  220.038691
# ...

# %% [markdown]
# Опираясь на полученные результаты, можем сказать:
#
# * в результате предобработки мы убрали дубликаты и привели данные к единому виду. Однако существует опасность, что мы некорректно определили нужные столбцы (и в учебном проекте мы не могли уточнить, в каком диапазоне и с какой точностью они должны быть). Подозрительные экстремальные значения были удалены, но остались просто редкие значения (например, 2% жирности молока).
#
# * вызывает опасение столбец с белком, который всегда равен 3%. Почти такая же ситуация с жирностью - крайне редко она достигает 2% (менее чем в 1% случаев), во всех остальных случаях она составляет 3%.
#
# * в стаде фермера удой молока колеблется от 5204 до 7222 кг, среднее значение составляет 6159 кг, а медианное - 6171. СПО колеблется от 0.84 до 0.96, среднее значение - 0.91, медианное - 0.93. ЭКЕ колеблется от 10 до 16, среднее и медианное значения очень близки - 14 и 14.127. Сырой протеин колеблется от 1660 до 2349, среднее значение - 1929, медианное - 1901.
#
# * в данных о коровах с Экофермы и в данных о коровах в стаде наблюдаются несовпадающие тенденции. В частности, в стаде фермера чаще встречаются другие породы, другие папы коров и другие пастбища. С этой точки зрения потенцально купленные на Экоферме коровы будут отличаться от самых распространенных коров стада.
#
# * Существует заметная положительная корреляция между удоем и ЭКЕ, а также удоем и СПО (0.8 и 0.7 соответственно).
#
# * Удой выше 6000 возможен только у коров, в чьем корме СПО выше 0.9.
#
# * Коровы моложе 2 лет в среднем характеризуются меньшим удоем, чем коровы старше 2 лет.
#
# * Молодые коровы получают корм с низким СПО и ЭКЕ - коровы моложе 2 лет практически не получают СПО более 0.9.
#
# * Коровы на корме с высоким СПО И ЭКЕ чаще дают вкусное молоко.
#
# * При ЭКЕ менее 13 СПО не поднимается выше 0.9, а при СПО выше 0.9 ЭКЕ не опускается ниже 13.
#
# * Молодые коровы практически не употребляют корм с содержанием сырого протеина выше 2000.
#
# * Коровы с папой породы Айдиал едят корм с большим количеством сырого протеина и дают больше удоя, чем коровы с папой породы Соверин.  Возможно, стоит подумать о покупке Айдиалов.
#
# * В связи с тем, что коровы разного возраста и разных пород не только дают разный удой и молоко разного качества, но и содержатся в очевидно разных условиях, то, возможно, стоит подумать, не стоит ли их содержание дороже упущенной выгоды от низкого удоя или менее вкусного молока.
#
# * В процессе работы над моделью мы попробовали убирать входные признаки, которые коррелируют между собой (порода папы и имя папы), возводить в квадрат признаки и переводить количественный признак (СПО) в категориальный. Но мы рассчитываем ее улучшить (возможно, за счет более качественной обработки данных, если там допущены ошибки).
#
# * В качестве способов улучшить модель можем предложить учитывать при покупке здоровье животного, сезон отела и массу тела животных.
#
# * В процессе работы мы увидели на графиках нелинейные взаимосвязи некоторых входных и целевого признаков. Признак СПО в зависимости от удоя делится на два интервала: до 0.9 и выше 0.92. В связи с этим он был преобразован и использовался в работе как категориальный.
#
# * Признак ЭКЕ тоже связан с целевым признаком нелинейно: график похож на часть параболы. В связи с этим ЭКЕ был возведен в квадрат.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Буренки найдены правильно. Молодец)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера v1**:
#
# Евгения, спасибо за  проект! Ты приложила много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты большой молодец!
#
# **Отмечу положительные моменты**:
#
# 1. Все разложено по полочкам, всегда понятен ход твоих мыслей, приятно смотреть
#
# 2. Отличные визуализации
#
# 3. На разных шагах проекта ты предлагала очень интересные решения и методы для их реализации. Хорошая работа!
#
# **На что стоит обратить внимание**:
#
# 1. Не отмечено наличие нелинейных связей в данных
#
# **Удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div class="alert alert-info">
# <b> Спасибо за рекомендации, Евгений, постаралась все исправить! Пункты про  нелинейность также включила в итоговые выводы.  </b>
# </div>
